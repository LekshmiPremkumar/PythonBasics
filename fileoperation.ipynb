# %%
import os

#os.mkdir("olddir")
os.mkdir("dir")

# %%
os.chdir("dir")

# %%
# !pwd
# Out:
# /Users/lek/Desktop/file operation/olddir/dir

# %%
for i in range(10):
    f=open('test_'+str(i)+'.txt',"w")
    f.write("jhfhjhhsdks\nfeg\nger\nbvgh\nghgj\nhehyrj\nvzfxwt\n134\nxget\nrg \nttg \nfg\nf\nfwrgrge\nruru\n")
    f.close()

# %%
 l=[]
for i in range(10):
   
    f=open('test_'+str(i)+'.txt',"r")
    read=f.readlines()
    for k in read:
        l.append(k)
    f.close()

# %%
f=open("newfile.txt","w")
for i in l:
    f.write(i)
f.close()

# %%
import shutil
for i in range(10):
    shutil.move("/Users/lek/Desktop/file operation/olddir/dir/"+'test_'+str(i)+'.txt',"/Users/lek/Desktop/file operation/chak")

# %%
pwd
# Out:
# '/Users/lek/Desktop/file operation/olddir/dir'

# %%
ls
# Out:
# newfile.txt

# %%
os.chdir("/Users/lek/Desktop/file operation/chak")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /var/folders/gb/f3p9f4v121q_wkpg_wxw1z680000gq/T/ipykernel_18179/1519817315.py in <module>
# ----> 1 os.chdir("/Users/lek/Desktop/file operation/chak")
#
# NotADirectoryError: [Errno 20] Not a directory: '/Users/lek/Desktop/file operation/chak'

# %%
pwd
# Out:
# '/Users/lek/Desktop/file operation/olddir/dir'

# %%
for i in range(10):
    f=open('test_'+str(i)+'.txt',"w")
    f.write("jhfhjhhsdks\nfeg\nger\nbvgh\nghgj\nhehyrj\nvzfxwt\n134\nxget\nrg \nttg \nfg\nf\nfwrgrge\nruru\n")
    f.close()

# %%
for i in range(10):
    shutil.move("/Users/lek/Desktop/file operation/olddir/dir/"+'test_'+str(i)+'.txt',"/Users/lek/Desktop/file operation/olddir/")

# %%
while True:
    f = os.listdir("/Users/lek/Desktop/file operation/olddir/")
    if len(f) > 0:
        for i in os.listdir("/Users/lek/Desktop/file operation/olddir/"):
            if i.endswith('.txt'):
                print(i)
                continue
            else:
                print(i)
# Out:
# .DS_Store
# test_8.txt
# test_9.txt
# test_2.txt
# test_3.txt
# test_1.txt
# test_0.txt
# test_4.txt
# test_5.txt
# dir
# test_7.txt
# test_6.txt
# .ipynb_checkpoints
# .DS_Store
# test_8.txt
# test_9.txt
# test_2.txt
# test_3.txt
# test_1.txt
# test_0.txt
# test_4.txt
# test_5.txt
# dir
# test_7.txt
# test_6.txt
# .ipynb_checkpoints
# .DS_Store
# test_8.txt
# test_9.txt
# test_2.txt
# test_3.txt
# test_1.txt
# test_0.txt
# test_4.txt
# test_5.txt
# dir
# test_7.txt
# test_6.txt
# .ipynb_checkpoints
# .DS_Store
# test_8.txt
# test_9.txt
# test_2.txt
# test_3.txt
# test_1.txt
# test_0.txt
# test_4.txt
# test_5.txt
# dir
# test_7.txt
# test_6.txt
# .ipynb_checkpoints
# .DS_Store
# test_8.txt
# test_9.txt
# test_2.txt
# test_3.txt
# test_1.txt
# test_0.txt
# test_4.txt
# test_5.txt
# dir
# test_7.txt
# test_6.txt
# .ipynb_checkpoints
# .DS_Store
# test_8.txt
# test_9.txt
# test_2.txt
# test_3.txt
# test_1.txt
# test_0.txt
# test_4.txt
# test_5.txt
# dir
# test_7.txt
# test_6.txt
# ...
